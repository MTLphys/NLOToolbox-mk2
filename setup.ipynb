# %%
#%pip install torch
# Out:
# Running cells with '.conda (Python 3.11.9)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\mattl\Work Programs\NLOToolbox-mk2\.conda ipykernel --update-deps --force-reinstall'

# %%
# %pip install torch torchvision torchaudio
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/159.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/159.8 MB 4.6 MB/s eta 0:00:35
#    ---------------------------------------- 0.8/159.8 MB 8.2 MB/s eta 0:00:20
#    ---------------------------------------- 1.9/159.8 MB 13.4 MB/s eta 0:00:12
#     --------------------------------------- 3.0/159.8 MB 16.1 MB/s eta 0:00:10
#    - -------------------------------------- 4.3/159.8 MB 18.4 MB/s eta 0:00:09
#    - -------------------------------------- 5.3/159.8 MB 18.9 MB/s eta 0:00:09
#    - -------------------------------------- 6.6/159.8 MB 20.0 MB/s eta 0:00:08
#    - -------------------------------------- 7.9/159.8 MB 21.1 MB/s eta 0:00:08
#    -- ------------------------------------- 9.3/159.8 MB 22.1 MB/s eta 0:00:07
# ...

# %%
# %pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.6 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.6 kB 640.0 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.6 kB 650.2 kB/s eta 0:00:01
#      -------------------------------------- 60.6/60.6 kB 645.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    ---------------------------------------- 0.2/46.2 MB 3.1 MB/s eta 0:00:15
#    ---------------------------------------- 0.5/46.2 MB 5.4 MB/s eta 0:00:09
#    - -------------------------------------- 1.4/46.2 MB 9.9 MB/s eta 0:00:05
#    - -------------------------------------- 2.2/46.2 MB 12.6 MB/s eta 0:00:04
#    -- ------------------------------------- 2.8/46.2 MB 12.7 MB/s eta 0:00:04
#    --- ------------------------------------ 4.0/46.2 MB 14.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.2/46.2 MB 15.7 MB/s eta 0:00:03
# ...

# %%
# %pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/164.2 kB ? eta -:--:--
#      -------------- ------------------------ 61.4/164.2 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 164.2/164.2 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.0 MB 7.2 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.0 MB 10.5 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.1/8.0 MB 14.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.3/8.0 MB 17.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.4/8.0 MB 18.9 MB/s eta 0:00:01
#    --------------------------- ------------ 5.6/8.0 MB 20.8 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/8.0 MB 21.1 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.0 MB 22.1 MB/s eta 0:00:01
# ...

# %%
# %pip install tqdm
# Out:
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      -------------------- ----------------- 30.7/57.6 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 57.6/57.6 kB 763.1 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.3 kB ? eta -:--:--
#    ---------------------------------------- 78.3/78.3 kB 2.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# %%
# !pip install cupy-cuda12x
# Out:
# ...
#    ---------------------------------------- 0.0/68.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/68.6 MB 991.0 kB/s eta 0:01:10
#    ---------------------------------------- 0.4/68.6 MB 4.9 MB/s eta 0:00:15
#    - -------------------------------------- 2.0/68.6 MB 15.6 MB/s eta 0:00:05
#    -- ------------------------------------- 3.9/68.6 MB 22.9 MB/s eta 0:00:03
#    --- ------------------------------------ 6.0/68.6 MB 27.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 7.9/68.6 MB 29.7 MB/s eta 0:00:03
#    ----- ---------------------------------- 9.7/68.6 MB 30.8 MB/s eta 0:00:02
#    ------ --------------------------------- 11.9/68.6 MB 43.5 MB/s eta 0:00:02
#    ------- -------------------------------- 13.6/68.6 MB 46.7 MB/s eta 0:00:02
#    --------- ------------------------------ 15.9/68.6 MB 43.7 MB/s eta 0:00:02
#    ---------- ----------------------------- 18.3/68.6 MB 43.7 MB/s eta 0:00:02
# ...

# %%
import cupy as cp 

def makeH(H,E,nstep,n,muij,En):
    for i in range(nstep*n):
        for j in range(nstep*n):
            if((cp.floor(i/n)==cp.floor(j/n))):
                H[i,j]=(i==j)*En[i%n]-muij[int(i%n),int(j%n)]*E[int(cp.floor(i/n))]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import cupy as cp
#       3 def makeH(H,E,nstep,n,muij,En):
#       4     for i in range(nstep*n):
#
# File c:\Users\mattl\Work Programs\NLOToolbox-mk2\.conda\Lib\site-packages\cupy\__init__.py:11
#       7 from cupy import _version
#      10 _environment._detect_duplicate_installation()  # NOQA
# ---> 11 _environment._setup_win32_dll_directory()  # NOQA
#      12 _environment._preload_library('cutensor')  # NOQA
#      15 try:
#
# File c:\Users\mattl\Work Programs\NLOToolbox-mk2\.conda\Lib\site-packages\cupy\_environment.py:235, in _setup_win32_dll_directory()
#     233 if cuda_bin_path is not None:
#     234     _log('Adding DLL search path: {}'.format(cuda_bin_path))
# --> 235     os.add_dll_directory(cuda_bin_path)
#     236 if wheel_libdir is not None:
# ...

# %%
import torch 
torch.__version__
# Out:
# '2.3.0+cpu'
